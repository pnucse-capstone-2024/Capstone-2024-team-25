# %%
from Problem_Type_Template.reading_1_problem_type_1_1 import generate_reading_1_problem_type_1_1
result = generate_reading_1_problem_type_1_1(difficulty="Normal", verbose=True, default_model="gpt-4o-mini")
display(result)
# Out:
# 연휴
# gpt-4o-mini |
# 휴가
#
# OpenAI Tokens Used: 58
#     Prompt Tokens: 56
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $4e-05
# Total Cost (KRW): ₩0.054
# --------------------------------------------------------------------------------------------------
# [{'문장': '차는 빨간색입니다.   버스는 노란색입니다.', '주제어': '도로'}, {'문장': '사상은 중요하다.   사상은 변할 수 있다.', '주제어': '사상'}]
# gpt-4o-mini |
# 휴가는 즐겁다.
# 휴가는 필요하다.
#
# OpenAI Tokens Used: 120
#     Prompt Tokens: 108
#     Completion Tokens: 12
# Successful Requests: 1
# Total Cost (USD): $9e-05
# Total Cost (KRW): ₩0.1215
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 휴식
#
# OpenAI Tokens Used: 76
#     Prompt Tokens: 74
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $6e-05
# Total Cost (KRW): ₩0.081
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 1. 비행
# 2. 전쟁
# 3. 농사
#
# OpenAI Tokens Used: 66
#     Prompt Tokens: 51
#     Completion Tokens: 15
# Successful Requests: 1
# Total Cost (USD): $5e-05
# Total Cost (KRW): ₩0.0675
# --------------------------------------------------------------------------------------------------
# gpt-4o |
# answer: 휴식
# explain: '휴식'은 '휴가'와 의미가 가장 유사하며, 문맥상 '휴식'이 '휴가'와 잘 어울립니다. '농사', '비행', '전쟁'은 문맥상 어울리지 않습니다.
#
# OpenAI Tokens Used: 153
#     Prompt Tokens: 89
#     Completion Tokens: 64
# Successful Requests: 1
# Total Cost (USD): $0.00306
# Total Cost (KRW): ₩4.131
# --------------------------------------------------------------------------------------------------
# {'example': '휴가는 즐겁다.   휴가는 필요하다.',
#  'selector': ['농사', '휴식', '비행', '전쟁'],
#  'answer': '휴식',
#  'eval_answer': '휴식',
#  'eval_explain': "'휴식'은 '휴가'와 의미가 가장 유사하며, 문맥상 '휴식'이 '휴가'와 잘 어울립니다. '농사', '비행', '전쟁'은 문맥상 어울리지 않습니다.",
#  'total_cost': 4.455}

# %%
from Problem_Type_Template.reading_1_problem_type_1_2 import generate_reading_1_problem_type_1_2
result = generate_reading_1_problem_type_1_2(target="명사", verbose=True, default_model="gpt-4o-mini")
display(result)
# Out:
# 대중적
# gpt-4o-mini |
# 인기
#
# OpenAI Tokens Used: 44
#     Prompt Tokens: 42
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $3e-05
# Total Cost (KRW): ₩0.0405
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 인기가 많습니다. 팬이 많아요.
#
# OpenAI Tokens Used: 105
#     Prompt Tokens: 95
#     Completion Tokens: 10
# Successful Requests: 1
# Total Cost (USD): $8e-05
# Total Cost (KRW): ₩0.108
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 1. 사랑
# 2. 꿈
# 3. 빛
#
# OpenAI Tokens Used: 85
#     Prompt Tokens: 72
#     Completion Tokens: 13
# Successful Requests: 1
# Total Cost (USD): $6e-05
# Total Cost (KRW): ₩0.081
# --------------------------------------------------------------------------------------------------
# 1. 사랑
# 2. 꿈
# 3. 빛
# {'example': '(    )가 많습니다. 팬이 많아요.',
#  'selector': ['꿈', '인기', '사랑', '빛'],
#  'answer': '인기',
#  'eval_answer': '인기',
#  'eval_explain': '인기가 많습니다. 팬이 많아요.',
#  'total_cost': 0.22949999999999998}

# %%
from Problem_Type_Template.reading_1_problem_type_1_2 import generate_reading_1_problem_type_1_2
result = generate_reading_1_problem_type_1_2(target="동사", verbose=True, default_model="gpt-4o-mini")
display(result)
# Out:
# 설날
# gpt-4o-mini |
# 새해
#
# OpenAI Tokens Used: 42
#     Prompt Tokens: 40
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $3e-05
# Total Cost (KRW): ₩0.0405
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 새해가 밝았습니다. 많은 소망이 이루어지길 바랍니다.
#
# OpenAI Tokens Used: 136
#     Prompt Tokens: 120
#     Completion Tokens: 16
# Successful Requests: 1
# Total Cost (USD): $0.0001
# Total Cost (KRW): ₩0.135
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 1. 감다
# 2. 다니다
# 3. 쌓다
#
# OpenAI Tokens Used: 91
#     Prompt Tokens: 75
#     Completion Tokens: 16
# Successful Requests: 1
# Total Cost (USD): $7e-05
# Total Cost (KRW): ₩0.0945
# --------------------------------------------------------------------------------------------------
# 1. 감다
# 2. 다니다
# 3. 쌓다
# {'example': '새해가 밝았습니다. 많은 소망이 이루어지길 (    ).',
#  'selector': ['바랍니다', '쌓다', '감다', '다니다'],
#  'answer': '바랍니다',
#  'eval_answer': '바랍니다',
#  'eval_explain': '새해가 밝았습니다. 많은 소망이 이루어지길 바랍니다.',
#  'total_cost': 0.27}

# %%
from Problem_Type_Template.reading_1_problem_type_1_2 import generate_reading_1_problem_type_1_2
result = generate_reading_1_problem_type_1_2(target="형용사", verbose=True, default_model="gpt-4o-mini")
display(result)
# Out:
# 발가락
# gpt-4o-mini |
# 발
#
# OpenAI Tokens Used: 42
#     Prompt Tokens: 41
#     Completion Tokens: 1
# Successful Requests: 1
# Total Cost (USD): $3e-05
# Total Cost (KRW): ₩0.0405
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 발이 아픕니다. 신발을 신습니다.
#
# OpenAI Tokens Used: 127
#     Prompt Tokens: 114
#     Completion Tokens: 13
# Successful Requests: 1
# Total Cost (USD): $0.0001
# Total Cost (KRW): ₩0.135
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 1. 기쁩니다
# 2. 차갑습니다
# 3. 밝습니다
#
# OpenAI Tokens Used: 101
#     Prompt Tokens: 84
#     Completion Tokens: 17
# Successful Requests: 1
# Total Cost (USD): $8e-05
# Total Cost (KRW): ₩0.108
# --------------------------------------------------------------------------------------------------
# 1. 기쁩니다
# 2. 차갑습니다
# 3. 밝습니다
# {'example': '발이 (    ). 신발을 신습니다.',
#  'selector': ['밝습니다', '기쁩니다', '아픕니다', '차갑습니다'],
#  'answer': '아픕니다',
#  'eval_answer': '아픕니다',
#  'eval_explain': '발이 아픕니다. 신발을 신습니다.',
#  'total_cost': 0.28350000000000003}

# %%
from Problem_Type_Template.reading_1_problem_type_1_2 import generate_reading_1_problem_type_1_2
result = generate_reading_1_problem_type_1_2(target="조사", verbose=True, default_model="gpt-4o-mini")
display(result)
# Out:
# 역사
# gpt-4o-mini |
# 과거
#
# OpenAI Tokens Used: 41
#     Prompt Tokens: 39
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $3e-05
# Total Cost (KRW): ₩0.0405
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 저는 어제 영화를 봤습니다. 친구는 지난 주에 여행을 갔습니다.
#
# OpenAI Tokens Used: 135
#     Prompt Tokens: 114
#     Completion Tokens: 21
# Successful Requests: 1
# Total Cost (USD): $0.0001
# Total Cost (KRW): ₩0.135
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 1. 에
# 2. 와
# 3. 의
#
# OpenAI Tokens Used: 78
#     Prompt Tokens: 66
#     Completion Tokens: 12
# Successful Requests: 1
# Total Cost (USD): $6e-05
# Total Cost (KRW): ₩0.081
# --------------------------------------------------------------------------------------------------
# 1. 에
# 2. 와
# 3. 의
# {'example': '저는 어제 영화(    ) 봤습니다. 친구는 지난 주에 여행을 갔습니다.',
#  'selector': ['에', '와', '를', '의'],
#  'answer': '를',
#  'eval_answer': '를',
#  'eval_explain': '저는 어제 영화를 봤습니다. 친구는 지난 주에 여행을 갔습니다.',
#  'total_cost': 0.2565}

# %%
from Problem_Type_Template.reading_1_problem_type_2 import generate_reading_1_problem_type_2

result = generate_reading_1_problem_type_2(default_model="gpt-4o-mini",verbose=True)
display(result)
# Out:
# [{'selector': {'1': '모임은 매주 토요일에 있습니다.', '2': '금요일 저녁 학교 운동장에서 모여요.', '3': '매주 금요일 저녁에 축구합니다.', '4': '매주 금요일 오후 6시에 운동장에서 만나요.'}, 'answer': {'1': '모임은 매주 토요일에 있습니다.'}, 'example': 'https://topikkorea.s3.amazonaws.com/topik_image/73292c0a-23ef-11ef-80ec-e5a43cd400fd.png'}]
# gpt-4o-mini |
# 1. 학교 운동장에서 축구해요.
# 2. 매주 금요일 저녁 6시에 모입니다.
# 3. 금요일 저녁에 다 함께 모여요.
#
# OpenAI Tokens Used: 218
#     Prompt Tokens: 178
#     Completion Tokens: 40
# Successful Requests: 1
# Total Cost (USD): $0.00016
# Total Cost (KRW): ₩0.216
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 모임은 매주 목요일에 있습니다.
#
# OpenAI Tokens Used: 138
#     Prompt Tokens: 128
#     Completion Tokens: 10
# Successful Requests: 1
# Total Cost (USD): $0.0001
# Total Cost (KRW): ₩0.135
# --------------------------------------------------------------------------------------------------
# 축구 동아리 모임
# 언제: 매주 금요일 저녁 6시
# ■ 어디서 : 학교 운동장
# 1. 학교 운동장에서 축구해요.
# 2. 매주 금요일 저녁 6시에 모입니다.
# 3. 금요일 저녁에 다 함께 모여요.
# 모임은 매주 목요일에 있습니다.
# {'example': 'https://topikkorea.s3.amazonaws.com/topik_image/73292c0a-23ef-11ef-80ec-e5a43cd400fd.png',
#  'selector': ['학교 운동장에서 축구해요.',
#   '금요일 저녁에 다 함께 모여요.',
#   '모임은 매주 목요일에 있습니다.',
#   '매주 금요일 저녁 6시에 모입니다.'],
#  'answer': '모임은 매주 목요일에 있습니다.',
#  'eval_answer': '모임은 매주 목요일에 있습니다.',
#  'explain': '',
#  'total_cost': 0.351}

# %%
from Problem_Type_Template.reading_1_problem_type_3 import generate_reading_1_problem_type_3

result = generate_reading_1_problem_type_3(default_model="gpt-4o-mini",verbose=True, default_type="일치")
display(result)
# Out:
# 지하도
# gpt-4o-mini |
# 터널
#
# OpenAI Tokens Used: 44
#     Prompt Tokens: 42
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $3e-05
# Total Cost (KRW): ₩0.0405
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 꽃잎
#
# OpenAI Tokens Used: 63
#     Prompt Tokens: 60
#     Completion Tokens: 3
# Successful Requests: 1
# Total Cost (USD): $5e-05
# Total Cost (KRW): ₩0.0675
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 가족
#
# OpenAI Tokens Used: 99
#     Prompt Tokens: 97
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $7e-05
# Total Cost (KRW): ₩0.0945
# --------------------------------------------------------------------------------------------------
# [{'주제어': '꽃잎', '문장': '고운털이 부드럽게 내려앉은 꽃잎은 아름다운 풍경을 만들어냅니다.'}, {'주제어': '가족', '문장': '가족은 저의 인생에서 가장 소중한 존재들입니다. 함께 보내는 시간은 항상 행복하고 따뜻합니다. 가족들과의 대화와 추억은 저에게 큰 힘이 됩니다. 함께하는 모든 순간을 소중히 여기며 더 많은 사랑을 주고 싶습니다.'}]
# gpt-4o-mini |
# 터널은 어두운 곳에서 빛을 찾아가는 길입니다. 그 안을 지나면 새로운 세상이 열리는 것처럼 느껴집니다. 터널을 지나고 나면 항상 희망과 기대가 가득합니다.
#
# OpenAI Tokens Used: 219
#     Prompt Tokens: 169
#     Completion Tokens: 50
# Successful Requests: 1
# Total Cost (USD): $0.00016
# Total Cost (KRW): ₩0.216
# --------------------------------------------------------------------------------------------------
# 터널은 어두운 곳에서 빛을 찾아가는 길입니다. 그 안을 지나면 새로운 세상이 열리는 것처럼 느껴집니다. 터널을 지나고 나면 항상 희망과 기대가 가득합니다.
# gpt-4o-mini |
# 선택지: 1. 터널은 밝은 곳입니다. 2. 터널은 어두운 곳입니다. 3. 터널은 길입니다. 4. 터널은 새로운 세상입니다.
# 정답: 1. 터널은 밝은 곳입니다.
#
# OpenAI Tokens Used: 228
#     Prompt Tokens: 166
#     Completion Tokens: 62
# Successful Requests: 1
# Total Cost (USD): $0.00017
# Total Cost (KRW): ₩0.2295
# --------------------------------------------------------------------------------------------------
# [('gpt-4o-mini', '선택지: 1. 터널은 밝은 곳입니다. 2. 터널은 어두운 곳입니다. 3. 터널은 길입니다. 4. 터널은 새로운 세상입니다.  \n정답: 1. 터널은 밝은 곳입니다.', 'OpenAI Tokens Used: 228\n    Prompt Tokens: 166\n    Completion Tokens: 62\nSuccessful Requests: 1\nTotal Cost (USD): $0.00017\nTotal Cost (KRW): ₩0.2295')]
# gpt-4o-mini |
# 1. 터널은 항상 밝은 곳입니다.
# 2. 터널을 지나면 어둠이 가득합니다.
# 3. 터널은 길이 아닌 벽입니다.
# 4. 터널은 희망이 없는 곳입니다.
#
# OpenAI Tokens Used: 167
#     Prompt Tokens: 113
#     Completion Tokens: 54
# Successful Requests: 1
# Total Cost (USD): $0.00013
# Total Cost (KRW): ₩0.1755
# --------------------------------------------------------------------------------------------------
# [('gpt-4o-mini', '1. 터널은 항상 밝은 곳입니다.  \n2. 터널을 지나면 어둠이 가득합니다.  \n3. 터널은 길이 아닌 벽입니다.  \n4. 터널은 희망이 없는 곳입니다.  ', 'OpenAI Tokens Used: 167\n    Prompt Tokens: 113\n    Completion Tokens: 54\nSuccessful Requests: 1\nTotal Cost (USD): $0.00013\nTotal Cost (KRW): ₩0.1755')]
# ['터널은 밝은 곳입니다.', '터널은 어두운 곳입니다.', '터널은 길입니다.', '터널은 새로운 세상입니다.', '터널은 밝은 곳입니다.']
# ['터널은 어두운 곳입니다.', '터널은 길입니다.', '터널은 새로운 세상입니다.']
# {'example': '터널은 어두운 곳에서 빛을 찾아가는 길입니다. 그 안을 지나면 새로운 세상이 열리는 것처럼 느껴집니다. 터널을 지나고 나면 항상 희망과 기대가 가득합니다.',
#  'selector': ['터널은 희망이 없는 곳입니다.',
#   '터널은 어두운 곳입니다.',
#   '터널을 지나면 어둠이 가득합니다.',
#   '터널은 항상 밝은 곳입니다.'],
#  'answer': '터널은 어두운 곳입니다.',
#  'eval_answer': '터널은 어두운 곳입니다.',
#  'explain': '',
#  'total_cost': 0.8235}

# %%
from Problem_Type_Template.reading_1_problem_type_4 import generate_reading_1_problem_type_4

result = generate_reading_1_problem_type_4(default_model="gpt-4o-mini",verbose=True)

display(result)
# Out:
# 술집
# gpt-4o-mini |
# 맥주
#
# OpenAI Tokens Used: 44
#     Prompt Tokens: 42
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $3e-05
# Total Cost (KRW): ₩0.0405
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 마법
#
# OpenAI Tokens Used: 81
#     Prompt Tokens: 79
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $6e-05
# Total Cost (KRW): ₩0.081
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 사진
#
# OpenAI Tokens Used: 75
#     Prompt Tokens: 74
#     Completion Tokens: 1
# Successful Requests: 1
# Total Cost (USD): $6e-05
# Total Cost (KRW): ₩0.081
# --------------------------------------------------------------------------------------------------
# [{'주제어': '마법', '문장': '마법은 세계를 놀라게 하는 힘이 있습니다. 마법사들은 마법을 사용하여 놀라운 일들을 이룹니다. 나는 마법에 대한 이야기를 듣는 것을 좋아합니다.', '선택지': ['마법은 세계를 지배하는 힘이 있습니다.', '마법을 배우고 싶습니다.', '마법사들은 일상 속에서도 마법을 사용합니다.', '나는 마법에 대한 이야기를 듣는 것을 좋아합니다.']}, {'주제어': '사진', '문장': '나는 사진 찍을 때 항상 셔터를 누르는 소리가 좋다. 그 소리를 듣는 순간, 나는 특별한 순간을 담고 있는 기분이 든다.', '선택지': ['나는 사진 찍는 것을 좋아합니다.', '나는 소리를 듣는 것을 좋아합니다.', '나는 특별한 순간을 즐깁니다.', '나는 사진 찍을 때 셔터 소리를 좋아합니다.']}]
# gpt-4o-mini |
# 맥주는 다양한 맛과 향을 가진 음료로, 친구들과의 소중한 순간을 함께 나누기에 완벽한 선택입니다. 나는 새로운 맥주를 시도하는 것을 즐기며, 각 지역의 특색 있는 양조장을 방문하는 것도 큰 재미입니다. 맥주 한 잔과 함께하는 여유로운 저녁은 나에게 큰 행복을 줍니다.
#
# OpenAI Tokens Used: 229
#     Prompt Tokens: 145
#     Completion Tokens: 84
# Successful Requests: 1
# Total Cost (USD): $0.00017
# Total Cost (KRW): ₩0.2295
# --------------------------------------------------------------------------------------------------
# 문장: 마법은 세계를 놀라게 하는 힘이 있습니다. 마법사들은 마법을 사용하여 놀라운 일들을 이룹니다. 나는 마법에 대한 이야기를 듣는 것을 좋아합니다. 선택지: 1. 마법은 세계를 지배하는 힘이 있습니다.
# 2. 마법을 배우고 싶습니다.
# 3. 마법사들은 일상 속에서도 마법을 사용합니다.
# 4. 나는 마법에 대한 이야기를 듣는 것을 좋아합니다.
# 문장: 나는 사진 찍을 때 항상 셔터를 누르는 소리가 좋다. 그 소리를 듣는 순간, 나는 특별한 순간을 담고 있는 기분이 든다. 선택지: 1. 나는 사진 찍는 것을 좋아합니다.
# 2. 나는 소리를 듣는 것을 좋아합니다.
# 3. 나는 특별한 순간을 즐깁니다.
# 4. 나는 사진 찍을 때 셔터 소리를 좋아합니다.
#
# 맥주는 다양한 맛과 향을 가진 음료로, 친구들과의 소중한 순간을 함께 나누기에 완벽한 선택입니다. 나는 새로운 맥주를 시도하는 것을 즐기며, 각 지역의 특색 있는 양조장을 방문하는 것도 큰 재미입니다. 맥주 한 잔과 함께하는 여유로운 저녁은 나에게 큰 행복을 줍니다.
# gpt-4o-mini |
# 선택지:
# 1. 나는 맥주를 마시는 것을 싫어합니다.
# 2. 친구들과의 순간을 소중히 여깁니다.
# 3. 나는 맥주를 만드는 방법에 관심이 많습니다.
# 4. 나는 새로운 맥주를 시도하는 것을 즐깁니다.
#
# 정답: 4. 나는 새로운 맥주를 시도하는 것을 즐깁니다.
#
# OpenAI Tokens Used: 447
#     Prompt Tokens: 355
#     Completion Tokens: 92
# Successful Requests: 1
# Total Cost (USD): $0.00034
# Total Cost (KRW): ₩0.459
# --------------------------------------------------------------------------------------------------
# 선택지:
# 1. 나는 맥주를 마시는 것을 싫어합니다.
# 2. 친구들과의 순간을 소중히 여깁니다.
# 3. 나는 맥주를 만드는 방법에 관심이 많습니다.
# 4. 나는 새로운 맥주를 시도하는 것을 즐깁니다.
#
# 정답: 4. 나는 새로운 맥주를 시도하는 것을 즐깁니다.
# gpt-4o |
# answer: 4. 나는 새로운 맥주를 시도하는 것을 즐깁니다.
# explain: 글의 중심 내용은 맥주를 즐기고, 새로운 맥주를 시도하며, 각 지역의 양조장을 방문하는 것에서 큰 재미를 느낀다는 것입니다. 따라서 "나는 새로운 맥주를 시도하는 것을 즐깁니다."가 가장 적절한 답입니다.
#
# OpenAI Tokens Used: 329
#     Prompt Tokens: 239
#     Completion Tokens: 90
# Successful Requests: 1
# Total Cost (USD): $0.00658
# Total Cost (KRW): ₩8.883
# --------------------------------------------------------------------------------------------------
# {'example': '맥주는 다양한 맛과 향을 가진 음료로, 친구들과의 소중한 순간을 함께 나누기에 완벽한 선택입니다. 나는 새로운 맥주를 시도하는 것을 즐기며, 각 지역의 특색 있는 양조장을 방문하는 것도 큰 재미입니다. 맥주 한 잔과 함께하는 여유로운 저녁은 나에게 큰 행복을 줍니다.',
#  'selector': ['나는 새로운 맥주를 시도하는 것을 즐깁니다.  ',
#   '나는 맥주를 만드는 방법에 관심이 많습니다.  ',
#   '친구들과의 순간을 소중히 여깁니다.  ',
#   '나는 맥주를 마시는 것을 싫어합니다.  '],
#  'answer': '나는 새로운 맥주를 시도하는 것을 즐깁니다.  ',
#  'eval_answer': '나는 새로운 맥주를 시도하는 것을 즐깁니다.  ',
#  'explain': '글의 중심 내용은 맥주를 즐기고, 새로운 맥주를 시도하며, 각 지역의 양조장을 방문하는 것에서 큰 재미를 느낀다는 것입니다. 따라서 "나는 새로운 맥주를 시도하는 것을 즐깁니다."가 가장 적절한 답입니다.',
#  'total_cost': 9.774}

# %%
from Problem_Type_Template.reading_1_problem_type_5 import generate_reading_1_problem_type_5

result = generate_reading_1_problem_type_5(default_model="gpt-4o-mini",verbose=True)

display(result)
# Out:
# 식빵
# gpt-4o-mini |
# 토스트
#
# OpenAI Tokens Used: 44
#     Prompt Tokens: 42
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $3e-05
# Total Cost (KRW): ₩0.0405
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 독서
#
# OpenAI Tokens Used: 130
#     Prompt Tokens: 128
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $0.0001
# Total Cost (KRW): ₩0.135
# --------------------------------------------------------------------------------------------------
# example_dict
# [{'주제어': '독서', '문장': '책을 읽는 것은 제 취향 중 하나( ㉠ ). 매일 저녁 책을 읽으면서 스트레스를 풀고 새로운 지식을 얻습니다. 독서는 제게 큰 즐거움을 주는 활동이며, 책 속의 이야기들이 현실에서 벗어나게 해줍니다. 책을 읽는 것은 제게 새로운 세계를 열어주는 것 같아서 끊임없이 독서 목록을 업데이트하고 있습니다.', '선택지': ['입니다', '입니다만', '입니다만', '입니다만'], '정답': '입니다'}, {'주제어': '독서', '문장': '책을 읽는 것은 제 취향 중 하나( ㉠ ). 매일 저녁 책을 읽으면서 스트레스를 풀고 새로운 지식을 얻습니다. 독서는 제게 큰 즐거움을 주는 활동이며, 책 속의 이야기들이 현실에서 벗어나게 해줍니다. 책을 읽는 것은 제게 새로운 세계를 열어주는 것 같아서 끊임없이 독서 목록을 업데이트하고 있습니다.', '선택지': ['저는 매일 저녁 책을 읽으면서 스트레스를 풉니다.', '독서는 제게 큰 스트레스를 주는 활동입니다.', '책을 읽는 것은 제게 큰 지루함을 줍니다.', '저는 책을 읽는 것을 싫어합니다.'], '정답': '저는 매일 저녁 책을 읽으면서 스트레스를 풉니다.'}]
# example_str
# 주제어: 독서 결과: 책을 읽는 것은 제 취향 중 하나입니다. 매일 저녁 책을 읽으면서 스트레스를 풀고 새로운 지식을 얻습니다. 독서는 제게 큰 즐거움을 주는 활동이며, 책 속의 이야기들이 현실에서 벗어나게 해줍니다. 책을 읽는 것은 제게 새로운 세계를 열어주는 것 같아서 끊임없이 독서 목록을 업데이트하고 있습니다.
# gpt-4o-mini |
# 토스트는 아침 식사로 아주 좋은 선택입니다. 바삭하게 구운 빵 위에 다양한 재료를 올릴 수 있어 맛이 다양합니다. 저는 종종 잼이나 아보카도를 올려서 먹습니다. 토스트는 간단하면서도 맛있고, 빠르게 준비할 수 있는 음식입니다.
#
# OpenAI Tokens Used: 241
#     Prompt Tokens: 170
#     Completion Tokens: 71
# Successful Requests: 1
# Total Cost (USD): $0.00018
# Total Cost (KRW): ₩0.243
# --------------------------------------------------------------------------------------------------
# 토스트는 아침 식사로 아주 좋은 선택입니다. 바삭하게 구운 빵 위에 (  ) 재료를 올릴 수 있어 맛이 다양합니다. 저는 종종 잼이나 아보카도를 올려서 먹습니다. 토스트는 간단하면서도 맛있고, 빠르게 준비할 수 있는 음식입니다.
# gpt-4o |
# 빈칸에 들어갈 알맞은 문제 선택지:
# 1. 여러 가지
# 2. 아무런
# 3. 적은
# 4. 한 가지
#
# 문장을 올바르게 서술한 문제 선택지:
# 1. 토스트는 아침 식사로 아주 나쁜 선택입니다.
# 2. 저는 토스트에 잼이나 아보카도를 올려서 먹습니다.
# 3. 토스트는 준비하는 데 시간이 많이 걸립니다.
# 4. 토스트는 맛이 없고 복잡한 음식입니다.
#
# OpenAI Tokens Used: 459
#     Prompt Tokens: 351
#     Completion Tokens: 108
# Successful Requests: 1
# Total Cost (USD): $0.00918
# Total Cost (KRW): ₩12.393
# --------------------------------------------------------------------------------------------------
# [('gpt-4o', '빈칸에 들어갈 알맞은 문제 선택지:\n1. 여러 가지\n2. 아무런\n3. 적은\n4. 한 가지\n\n문장을 올바르게 서술한 문제 선택지:\n1. 토스트는 아침 식사로 아주 나쁜 선택입니다.\n2. 저는 토스트에 잼이나 아보카도를 올려서 먹습니다.\n3. 토스트는 준비하는 데 시간이 많이 걸립니다.\n4. 토스트는 맛이 없고 복잡한 음식입니다.', 'OpenAI Tokens Used: 459\n    Prompt Tokens: 351\n    Completion Tokens: 108\nSuccessful Requests: 1\nTotal Cost (USD): $0.00918\nTotal Cost (KRW): ₩12.393')]
# gpt-4o |
# 문제 1:
# answer: 1. 여러 가지
# explain: 문맥상 토스트 위에 다양한 재료를 올릴 수 있다는 의미를 전달하기 위해 "여러 가지"가 가장 적합합니다.
#
# 문제 2:
# answer: 2. 저는 토스트에 잼이나 아보카도를 올려서 먹습니다.
# explain: 주어진 예문에서 "저는 종종 잼이나 아보카도를 올려서 먹습니다."라는 문장이 있으므로, 이와 가장 일치하는 선택지는 2번입니다.
#
# OpenAI Tokens Used: 368
#     Prompt Tokens: 249
#     Completion Tokens: 119
# Successful Requests: 1
# Total Cost (USD): $0.00736
# Total Cost (KRW): ₩9.936
# --------------------------------------------------------------------------------------------------
# answer_1 : 여러 가지
# masking_data : 다양한
# {'example': '토스트는 아침 식사로 아주 좋은 선택입니다. 바삭하게 구운 빵 위에 ( ㉠ ) 재료를 올릴 수 있어 맛이 다양합니다. 저는 종종 잼이나 아보카도를 올려서 먹습니다. 토스트는 간단하면서도 맛있고, 빠르게 준비할 수 있는 음식입니다.',
#  'questions': [{'question': '( ㉠ )에 들어갈 말로 가장 알맞은 것을 고르십시오.',
#    'selector': ['다양한', '한 가지', '적은', '아무런'],
#    'answer': '다양한',
#    'eval_answer': '다양한',
#    'eval_explain': '문맥상 토스트 위에 다양한 재료를 올릴 수 있다는 의미를 전달하기 위해 "다양한"가 가장 적합합니다.'},
#   {'question': '<보기>의 내용과 맞는 것을 고르십시오.',
#    'selector': ['토스트는 아침 식사로 아주 나쁜 선택입니다.',
#     '토스트는 맛이 없고 복잡한 음식입니다.',
#     '저는 토스트에 잼이나 아보카도를 올려서 먹습니다.',
#     '토스트는 준비하는 데 시간이 많이 걸립니다.'],
#    'answer': '저는 토스트에 잼이나 아보카도를 올려서 먹습니다.',
#    'eval_answer': '저는 토스트에 잼이나 아보카도를 올려서 먹습니다.',
#    'eval_explain': '주어진 예문에서 "저는 종종 잼이나 아보카도를 올려서 먹습니다."라는 문장이 있으므로, 이와 가장 일치하는 선택지는 2번입니다.'}],
#  'total_cost': 22.747500000000002}

# %%
from Problem_Type_Template.reading_1_problem_type_6 import generate_reading_1_problem_type_6

result = generate_reading_1_problem_type_6(default_model="gpt-4o-mini",verbose=True)

display(result)
# Out:
# 토대
# gpt-4o-mini |
# 기초
#
# OpenAI Tokens Used: 42
#     Prompt Tokens: 40
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $3e-05
# Total Cost (KRW): ₩0.0405
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 진통제
#
# OpenAI Tokens Used: 111
#     Prompt Tokens: 108
#     Completion Tokens: 3
# Successful Requests: 1
# Total Cost (USD): $8e-05
# Total Cost (KRW): ₩0.108
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 식료품
#
# OpenAI Tokens Used: 126
#     Prompt Tokens: 123
#     Completion Tokens: 3
# Successful Requests: 1
# Total Cost (USD): $9e-05
# Total Cost (KRW): ₩0.1215
# --------------------------------------------------------------------------------------------------
# example_dict
# [{'주제어': '식료품', '문장': ' 가끔씩 슈퍼마켓에서 할인 행사를 하는 것을 보면 식료품을 사야겠다는 생각이 듭니다.  요즘은 식료품가격이 올라가서 가계 경제에 부담이 됩니다.  그래서 집에서 직접 요리를 해먹는 것이 절약에 도움이 됩니다.  주말에는 시장에 가서 신선한 식료품을 구입해야겠어요.', '선택지': ['(가) - (다) - (나) - (라)', '(나) - (라) - (다) - (가)', '(나) - (가) - (다) - (라)', '(나) - (다) - (가) - (라)']}, {'주제어': '진통제', '문장': ' 진통제는 통증을 완화하는 약물입니다.  일반적으로 수술 후나 출산 시에 사용됩니다.  진통제를 복용하면 통증이 줄어들어 편안해집니다.  그러나 오버도스를 하면 심각한 부작용이 발생할 수 있으니 주의해야 합니다.', '선택지': ['(라) - (가) - (다) - (나)', '(다) - (가) - (나) - (라)', '(라) - (나) - (다) - (가)', '(나) - (가) - (다) - (라)']}]
# example_str
# 주제어: 식료품 결과:  가끔씩 슈퍼마켓에서 할인 행사를 하는 것을 보면 식료품을 사야겠다는 생각이 듭니다.  요즘은 식료품가격이 올라가서 가계 경제에 부담이 됩니다.  그래서 집에서 직접 요리를 해먹는 것이 절약에 도움이 됩니다.  주말에는 시장에 가서 신선한 식료품을 구입해야겠어요. 주제어: 진통제 결과:  진통제는 통증을 완화하는 약물입니다.  일반적으로 수술 후나 출산 시에 사용됩니다.  진통제를 복용하면 통증이 줄어들어 편안해집니다.  그러나 오버도스를 하면 심각한 부작용이 발생할 수 있으니 주의해야 합니다.
# gpt-4o-mini |
# 기초는 모든 학문의 토대가 되는 중요한 개념입니다. 기초를 잘 다져야 이후의 학습이 수월해집니다. 예를 들어, 수학의 기초가 튼튼해야 복잡한 문제를 해결할 수 있습니다. 따라서 기초를 소홀히 하지 않고 꾸준히 학습하는 것이 필요합니다.
#
# OpenAI Tokens Used: 321
#     Prompt Tokens: 245
#     Completion Tokens: 76
# Successful Requests: 1
# Total Cost (USD): $0.00024
# Total Cost (KRW): ₩0.324
# --------------------------------------------------------------------------------------------------
# {'example': '(가) 따라서 기초를 소홀히 하지 않고 꾸준히 학습하는 것이 필요합니다. (나) 예를 들어, 수학의 기초가 튼튼해야 복잡한 문제를 해결할 수 있습니다. (다) 기초를 잘 다져야 이후의 학습이 수월해집니다. (라) 기초는 모든 학문의 토대가 되는 중요한 개념입니다.',
#  'selector': ['(가) - (다) - (나) - (라)',
#   '(라) - (다) - (나) - (가)',
#   '(다) - (나) - (라) - (가)',
#   '(다) - (나) - (가) - (라)'],
#  'answer': '(라) - (다) - (나) - (가)',
#  'eval_answer': '(라) - (다) - (나) - (가)',
#  'eval_explain': '기초는 모든 학문의 토대가 되는 중요한 개념입니다. 기초를 잘 다져야 이후의 학습이 수월해집니다. 예를 들어, 수학의 기초가 튼튼해야 복잡한 문제를 해결할 수 있습니다. 따라서 기초를 소홀히 하지 않고 꾸준히 학습하는 것이 필요합니다.',
#  'total_cost': 0.5940000000000001}

# %%
from Problem_Type_Template.reading_1_problem_type_7 import generate_reading_1_problem_type_7
result = generate_reading_1_problem_type_7(default_model="gpt-3.5-turbo", verbose=True)
display(result)
# Out:
# {'example': 'https://topikkorea.s3.amazonaws.com/topik_image/746db4e5-23ef-11ef-90ad-e5a43cd400fd.png',
#  'questions': [{'question': '이 글을 쓴 의도와 가장 가까운 것을 고르십시오.',
#    'selector': ['청소 이유를 설명하려고',
#     '청소 계획을 물어보려고',
#     '청소 날짜와 시간을 알리려고',
#     '청소 장소를 바꾸려고'],
#    'answer': '청소 날짜와 시간을 알리려고',
#    'eval_answer': '청소 날짜와 시간을 알리려고',
#    'eval_explain': ''},
#   {'question': '이 글의 내용과 같은 것을 고르십시오.',
#    'selector': ['이틀 동안 주차장 청소를 할 겁니다.',
#     '지하 주차장 물청소는 아홉 시까지 합니다.',
#     '7월 22일까지 다른 주차장을 이용해야 합니다.',
#     '주차장 청소는 화요일에 시작할 겁니다.'],
#    'answer': '이틀 동안 주차장 청소를 할 겁니다.',
#    'eval_answer': '이틀 동안 주차장 청소를 할 겁니다.',
#    'eval_explain': ''}],
#  'total_cost': 0}

# %%
from Problem_Type_Template.reading_1_problem_type_8_1 import generate_reading_1_problem_type_8_1

result = generate_reading_1_problem_type_8_1(default_model="gpt-4o-mini",verbose=True)

display(result)
# Out:
# 게
# gpt-4o-mini |
# 바다
#
# OpenAI Tokens Used: 42
#     Prompt Tokens: 40
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $3e-05
# Total Cost (KRW): ₩0.0405
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 기술
#
# OpenAI Tokens Used: 146
#     Prompt Tokens: 144
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $0.00011
# Total Cost (KRW): ₩0.1485
# --------------------------------------------------------------------------------------------------
# example_dict
# [{'주제어': '기술', '문장': '최근에 기술이 발전함에 따라 우리 주변에서 사용되는 기술들이 많이 ( ㉠ ). 스마트폰, 태블릿, 노트북 등 다양한 전자기기들이 우리의 일상생활에 깊숙이 뿌리를 내리고 있습니다. 저는 이러한 기술들을 잘 활용하여 일을 보다 효율적으로 처리할 수 있게 되었습니다. 또한, 인공지능 기술의 발전으로 우리의 삶이 더욱 편리해지고 있습니다. 미래에는 더욱 더 혁신적인 기술들이 나오게 될 것으로 기대됩니다.', '선택지': ['사라지고 있습니다', '발전하고 있습니다', '감소하고 있습니다', '퇴보하고 있습니다'], '정답': '발전하고 있습니다'}, {'주제어': '기술', '문장': '최근에 기술이 발전함에 따라 우리 주변에서 사용되는 기술들이 많이 ( ㉠ ). 스마트폰, 태블릿, 노트북 등 다양한 전자기기들이 우리의 일상생활에 깊숙이 뿌리를 내리고 있습니다. 저는 이러한 기술들을 잘 활용하여 일을 보다 효율적으로 처리할 수 있게 되었습니다. 또한, 인공지능 기술의 발전으로 우리의 삶이 더욱 편리해지고 있습니다. 미래에는 더욱 더 혁신적인 기술들이 나오게 될 것으로 기대됩니다.', '선택지': ['최근에 기술이 발전함에 따라 우리의 삶이 불편해지고 있습니다.', '스마트폰, 태블릿, 노트북 등 다양한 전자기기들이 우리의 일상생활에 깊숙이 뿌리를 내리고 있습니다.', '저는 이러한 기술들을 잘 활용하여 일을 비효율적으로 처리할 수 있게 되었습니다.', '인공지능 기술의 발전으로 우리의 삶이 더욱 불편해지고 있습니다.'], '정답': '스마트폰, 태블릿, 노트북 등 다양한 전자기기들이 우리의 일상생활에 깊숙이 뿌리를 내리고 있습니다.'}]
# example_str
# 주제어: 기술 결과: 최근에 기술이 발전함에 따라 우리 주변에서 사용되는 기술들이 많이 발전하고 있습니다. 스마트폰, 태블릿, 노트북 등 다양한 전자기기들이 우리의 일상생활에 깊숙이 뿌리를 내리고 있습니다. 저는 이러한 기술들을 잘 활용하여 일을 보다 효율적으로 처리할 수 있게 되었습니다. 또한, 인공지능 기술의 발전으로 우리의 삶이 더욱 편리해지고 있습니다. 미래에는 더욱 더 혁신적인 기술들이 나오게 될 것으로 기대됩니다.
# gpt-4o-mini |
# 바다는 지구의 생태계에서 중요한 역할을 하고 있습니다. 다양한 해양 생물들이 서식하며, 그들은 우리의 식량 공급에도 큰 기여를 하고 있습니다. 또한, 바다는 기후 조절에도 중요한 영향을 미치고 있습니다. 많은 사람들은 바다를 여행지로 선택하여 휴식을 취하고 자연의 아름다움을 즐깁니다. 그러나 바다 오염과 기후 변화로 인해 해양 생태계가 위협받고 있는 상황입니다. 우리는 바다를 보호하고 지속 가능한 방법으로 이용해야 할 필요성이 있습니다.
#
# OpenAI Tokens Used: 290
#     Prompt Tokens: 168
#     Completion Tokens: 122
# Successful Requests: 1
# Total Cost (USD): $0.00022
# Total Cost (KRW): ₩0.297
# --------------------------------------------------------------------------------------------------
# gpt-4o |
# 문장을 올바르게 서술한 문제 선택지:
#
# 1. 바다는 지구의 생태계에서 중요한 역할을 하고 있습니다.
# 2. 바다는 우리의 식량 공급에 큰 기여를 하지 않습니다.
# 3. 많은 사람들은 바다를 여행지로 선택하지 않습니다.
# 4. 우리는 바다를 보호할 필요가 없습니다.
#
# OpenAI Tokens Used: 496
#     Prompt Tokens: 424
#     Completion Tokens: 72
# Successful Requests: 1
# Total Cost (USD): $0.00992
# Total Cost (KRW): ₩13.392
# --------------------------------------------------------------------------------------------------
# [('gpt-4o', '문장을 올바르게 서술한 문제 선택지:\n\n1. 바다는 지구의 생태계에서 중요한 역할을 하고 있습니다.\n2. 바다는 우리의 식량 공급에 큰 기여를 하지 않습니다.\n3. 많은 사람들은 바다를 여행지로 선택하지 않습니다.\n4. 우리는 바다를 보호할 필요가 없습니다.', 'OpenAI Tokens Used: 496\n    Prompt Tokens: 424\n    Completion Tokens: 72\nSuccessful Requests: 1\nTotal Cost (USD): $0.00992\nTotal Cost (KRW): ₩13.392')]
# gpt-4o |
# answer: 1. 바다는 지구의 생태계에서 중요한 역할을 하고 있습니다.
# explain: 본문에서 바다는 지구의 생태계에서 중요한 역할을 하고 있으며, 다양한 해양 생물들이 서식하고 우리의 식량 공급에도 큰 기여를 한다고 언급하고 있습니다. 따라서 1번 문장이 올바르게 서술된 문장입니다. 2번, 3번, 4번 선택지는 본문의 내용과 일치하지 않습니다.
#
# OpenAI Tokens Used: 364
#     Prompt Tokens: 260
#     Completion Tokens: 104
# Successful Requests: 1
# Total Cost (USD): $0.00728
# Total Cost (KRW): ₩9.828
# --------------------------------------------------------------------------------------------------
# ['바다는 지구의 생태계에서 중요한 역할을 하고 있습니다.', ' 다양한 해양 생물들이 서식하며, 그들은 우리의 식량 공급에도 큰 기여를 하고 있습니다.', ' 또한, 바다는 기후 조절에도 중요한 영향을 미치고 있습니다.', ' 많은 사람들은 바다를 여행지로 선택하여 휴식을 취하고 자연의 아름다움을 즐깁니다.', ' 그러나 바다 오염과 기후 변화로 인해 해양 생태계가 위협받고 있는 상황입니다.', ' 우리는 바다를 보호하고 지속 가능한 방법으로 이용해야 할 필요성이 있습니다.']
# 3
#  그러나 바다 오염과 기후 변화로 인해 해양 생태계가 위협받고 있는 상황입니다.
# {'example': '바다는 지구의 생태계에서 중요한 역할을 하고 있습니다. (㉠) 다양한 해양 생물들이 서식하며, 그들은 우리의 식량 공급에도 큰 기여를 하고 있습니다. (㉡) 또한, 바다는 기후 조절에도 중요한 영향을 미치고 있습니다. (㉢) 많은 사람들은 바다를 여행지로 선택하여 휴식을 취하고 자연의 아름다움을 즐깁니다. (㉣) 우리는 바다를 보호하고 지속 가능한 방법으로 이용해야 할 필요성이 있습니다.',
#  'questions': [{'question': '다음 문장이 들어갈 곳으로 가장 알맞은 것을 고르십시오.',
#    'example': ' 그러나 바다 오염과 기후 변화로 인해 해양 생태계가 위협받고 있는 상황입니다.',
#    'selector': ['㉠', '㉡', '㉢', '㉣'],
#    'answer': '㉣',
#    'eval_answer': '㉣',
#    'eval_explain': ''},
#   {'question': '윗글의 내용과 같은 것을 고르십시오.',
#    'selector': ['바다는 우리의 식량 공급에 큰 기여를 하지 않습니다.',
#     '바다는 지구의 생태계에서 중요한 역할을 하고 있습니다.',
#     '많은 사람들은 바다를 여행지로 선택하지 않습니다.',
#     '우리는 바다를 보호할 필요가 없습니다.'],
#    'answer': '바다는 지구의 생태계에서 중요한 역할을 하고 있습니다.',
#    'eval_answer': '바다는 지구의 생태계에서 중요한 역할을 하고 있습니다.',
#    'eval_explain': '본문에서 바다는 지구의 생태계에서 중요한 역할을 하고 있으며, 다양한 해양 생물들이 서식하고 우리의 식량 공급에도 큰 기여를 한다고 언급하고 있습니다. 따라서 1번 문장이 올바르게 서술된 문장입니다. 2번, 3번, 4번 선택지는 본문의 내용과 일치하지 않습니다.'}],
#  'total_cost': 23.706}

# %%
from Problem_Type_Template.reading_1_problem_type_8_2 import generate_reading_1_problem_type_8_2

result = generate_reading_1_problem_type_8_2(default_model="gpt-4o-mini",verbose=True)

display(result)
# Out:
# 저녁
# gpt-4o-mini |
# 식사
#
# OpenAI Tokens Used: 43
#     Prompt Tokens: 41
#     Completion Tokens: 2
# Successful Requests: 1
# Total Cost (USD): $3e-05
# Total Cost (KRW): ₩0.0405
# --------------------------------------------------------------------------------------------------
# gpt-4o-mini |
# 선생님
#
# OpenAI Tokens Used: 151
#     Prompt Tokens: 148
#     Completion Tokens: 3
# Successful Requests: 1
# Total Cost (USD): $0.00011
# Total Cost (KRW): ₩0.1485
# --------------------------------------------------------------------------------------------------
# example_dict
# [{'주제어': '선생님', '문장': '선생님은 학생들에게 지식을 전달하고 가르치는 역할을 합니다. 학생들은 선생님을 ( ㉠ ). 선생님은 학생들의 발전을 위해 노력하며, 그들의 꿈을 이루도록 도와줍니다. 선생님의 가르침은 학생들의 미래를 밝게 만들어줍니다. 선생님의 따뜻한 조언과 격려는 학생들에게 큰 힘이 됩니다. 선생님의 노고에 감사를 표하고, 그들의 노력을 인정해주어야 합니다.', '선택지': ['존경하고 신뢰합니다.', '무시하고 비난합니다.', '의심하고 회피합니다.', '경멸하고 멀리합니다.'], '정답': '존경하고 신뢰합니다.'}, {'주제어': '선생님', '문장': '선생님은 학생들에게 지식을 전달하고 가르치는 역할을 합니다. 학생들은 선생님을 ( ㉠ ). 선생님은 학생들의 발전을 위해 노력하며, 그들의 꿈을 이루도록 도와줍니다. 선생님의 가르침은 학생들의 미래를 밝게 만들어줍니다. 선생님의 따뜻한 조언과 격려는 학생들에게 큰 힘이 됩니다. 선생님의 노고에 감사를 표하고, 그들의 노력을 인정해주어야 합니다.', '선택지': ['선생님은 학생들의 발전을 방해합니다.', '선생님은 학생들의 꿈을 이루도록 도와줍니다.', '선생님은 학생들의 미래를 어둡게 만듭니다.', '선생님은 학생들에게 무관심합니다.'], '정답': '선생님은 학생들의 꿈을 이루도록 도와줍니다.'}]
# example_str
# 주제어: 선생님 결과: 선생님은 학생들에게 지식을 전달하고 가르치는 역할을 합니다. 학생들은 선생님을 존경하고 신뢰합니다.. 선생님은 학생들의 발전을 위해 노력하며, 그들의 꿈을 이루도록 도와줍니다. 선생님의 가르침은 학생들의 미래를 밝게 만들어줍니다. 선생님의 따뜻한 조언과 격려는 학생들에게 큰 힘이 됩니다. 선생님의 노고에 감사를 표하고, 그들의 노력을 인정해주어야 합니다.
# gpt-4o-mini |
# 식사는 하루의 중요한 부분 중 하나입니다. 우리는 아침, 점심, 저녁 세 끼를 먹습니다. 식사는 우리에게 에너지를 주고 건강을 유지하는 데 도움을 줍니다. 가족이나 친구와 함께 식사하는 것은 소중한 시간을 만듭니다. 다양한 음식을 즐기며 새로운 맛을 경험하는 것도 식사의 큰 즐거움입니다.
#
# OpenAI Tokens Used: 280
#     Prompt Tokens: 196
#     Completion Tokens: 84
# Successful Requests: 1
# Total Cost (USD): $0.00021
# Total Cost (KRW): ₩0.2835
# --------------------------------------------------------------------------------------------------
# 식사는 하루의 중요한 부분 중 하나입니다. 우리는 아침, 점심, 저녁 세 (  ). 식사는 우리에게 에너지를 주고 건강을 유지하는 데 도움을 줍니다. 가족이나 친구와 함께 식사하는 것은 소중한 시간을 만듭니다. 다양한 음식을 즐기며 새로운 맛을 경험하는 것도 식사의 큰 즐거움입니다.
# gpt-4o |
# 빈칸에 들어갈 알맞은 말 고르기 문제 선택지:
# 1. 끼의 식사를 합니다.
# 2. 시간에 운동합니다.
# 3. 번의 여행을 갑니다.
# 4. 번의 회의를 합니다.
#
# 문장을 올바르게 서술한 문제 선택지:
# 1. 식사는 우리에게 에너지를 빼앗습니다.
# 2. 식사는 건강을 해칩니다.
# 3. 식사는 소중한 시간을 만듭니다.
# 4. 식사는 새로운 맛을 경험하지 못합니다.
#
# OpenAI Tokens Used: 528
#     Prompt Tokens: 416
#     Completion Tokens: 112
# Successful Requests: 1
# Total Cost (USD): $0.01056
# Total Cost (KRW): ₩14.256
# --------------------------------------------------------------------------------------------------
# [('gpt-4o', '빈칸에 들어갈 알맞은 말 고르기 문제 선택지:\n1. 끼의 식사를 합니다.\n2. 시간에 운동합니다.\n3. 번의 여행을 갑니다.\n4. 번의 회의를 합니다.\n\n문장을 올바르게 서술한 문제 선택지:\n1. 식사는 우리에게 에너지를 빼앗습니다.\n2. 식사는 건강을 해칩니다.\n3. 식사는 소중한 시간을 만듭니다.\n4. 식사는 새로운 맛을 경험하지 못합니다.', 'OpenAI Tokens Used: 528\n    Prompt Tokens: 416\n    Completion Tokens: 112\nSuccessful Requests: 1\nTotal Cost (USD): $0.01056\nTotal Cost (KRW): ₩14.256')]
# gpt-4o |
# 문제 1:
# answer: 1. 끼의 식사를 합니다.
# explain: 문맥상 식사에 대한 내용이므로 "끼의 식사를 합니다."가 가장 적절합니다.
#
# 문제 2:
# answer: 3. 식사는 소중한 시간을 만듭니다.
# explain: 식사에 대한 긍정적인 측면을 설명하는 문장이므로 "식사는 소중한 시간을 만듭니다."가 올바른 선택입니다.
#
# OpenAI Tokens Used: 363
#     Prompt Tokens: 261
#     Completion Tokens: 102
# Successful Requests: 1
# Total Cost (USD): $0.00726
# Total Cost (KRW): ₩9.801
# --------------------------------------------------------------------------------------------------
# {'example': '식사는 하루의 중요한 부분 중 하나입니다. 우리는 아침, 점심, 저녁 세 ( ㉠ ). 식사는 우리에게 에너지를 주고 건강을 유지하는 데 도움을 줍니다. 가족이나 친구와 함께 식사하는 것은 소중한 시간을 만듭니다. 다양한 음식을 즐기며 새로운 맛을 경험하는 것도 식사의 큰 즐거움입니다.',
#  'questions': [{'question': '㉠ 에 들어갈 알맞은 말을 고르십시오.',
#    'selector': ['번의 회의를 합니다.', '끼의 식사를 합니다.', '시간에 운동합니다.', '번의 여행을 갑니다.'],
#    'answer': '끼의 식사를 합니다.',
#    'eval_answer': '끼의 식사를 합니다.',
#    'eval_explain': '문맥상 식사에 대한 내용이므로 "끼의 식사를 합니다."가 가장 적절합니다.'},
#   {'question': '이 글의 내용과 같은 것을 고르십시오.',
#    'selector': ['식사는 건강을 해칩니다.',
#     '식사는 소중한 시간을 만듭니다.',
#     '식사는 우리에게 에너지를 빼앗습니다.',
#     '식사는 새로운 맛을 경험하지 못합니다.'],
#    'answer': '식사는 소중한 시간을 만듭니다.',
#    'eval_answer': '식사는 소중한 시간을 만듭니다.',
#    'eval_explain': '식사에 대한 긍정적인 측면을 설명하는 문장이므로 "식사는 소중한 시간을 만듭니다."가 올바른 선택입니다.'}],
#  'total_cost': 24.5295}
